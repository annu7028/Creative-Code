# %%
import pandas as pd
import altair as alt
from vega_datasets import data

# %% [markdown]
# # Dataframe
#
# Connecting to API, setting up Dataframe, and cleaning data to include relevant exploration

# %%
file = pd.read_json('https://makeup-api.herokuapp.com/api/v1/products.json?product_type=foundation')
df = pd.DataFrame(file)

#rename columns in dataframe
df.rename(columns={'id': 'ID', 'brand': 'Brand', 'name':'Name', 'price':'Price', 'rating': 'Rating', 'category': 'Category'}, inplace=True)
# drop all entries where rating = NaN and brand = null
df.dropna(subset=['Rating', 'Brand'], inplace=True)
df = df.reset_index()
#remove price_sign, currency, product_type, created_at, updated_at, product_api_url
df = df.drop(columns=['index', 'price_sign', 'currency', 'product_type', 'created_at', 'updated_at', 'product_api_url'])

# %%
#Adjust datframe to take product colors array, count the number of objects in that array 
#and place that number in a new "Color Count" column
color_counts = []
#iterate over each row in the dataframe
for index, row in df.iterrows():
    #get the length of product_colors
    color_counts.append(len(row['product_colors']))

df['Color Count'] = color_counts
df
# Out:
#      ID               Brand  \
# 0   389            marcelle
# 1   388  physicians formula
# 2   387  physicians formula
# 3   386           covergirl
# 4   385               sante
# 5   384           covergirl
# 6   383              revlon
# 7   382          maybelline
# 8   381              revlon
# 9   380          maybelline
# 10  379          maybelline
# 11  378              e.l.f.
# 12  374  physicians formula
# 13  373                 nyx
# 14  371              milani
# 15  369  physicians formula
# 16  368  physicians formula
# 17  367          pure anada
# 18  366          maybelline
# 19  365  physicians formula
# 20  364          pure anada
# 21  356      mineral fusion
# 22  354          maybelline
# 23  353          maybelline
# 24  352                 nyx
# 25  350             l'oreal
# 26  349           covergirl
# 27  344           covergirl
# 28  341           covergirl
# 29  340  physicians formula
# 30  338           covergirl
# 31  336              revlon
# 32  335             l'oreal
# 33  334     cargo cosmetics
# 34  333  physicians formula
# 35  332           annabelle
# 36  331               almay
# 37  330             l'oreal
# 38  329               almay
# 39  328               almay
# 40  327           covergirl
# 41  326             l'oreal
# 42  325             l'oreal
# 43  324              revlon
# 44  323        dr. hauschka
# 45  322              e.l.f.
# 46  321          maybelline
# 47  320          maybelline
# 48  319              revlon
# 49  318             l'oreal
# 50  317          maybelline
# 51  316          pure anada
# 52  315              e.l.f.
#
#                                                  Name  Price  \
# 0                  Marcelle BB Cream-to-Powder Makeup  22.99
# 1   Physicians Formula Super BB All-in-1 Beauty Ba...  12.99
# 2   Physicians Formula Nude Wear Touch of Glow Sti...  12.99
# 3         CoverGirl & Olay Simply Ageless Foundation   15.99
# 4                         Sante Soft Cream Foundation  27.49
# 5     CoverGirl Ultimate Finish Liquid Powder Makeup    9.99
# 6               Revlon Colorstay Whipped Creme Makeup  19.99
# 7           Maybelline Dream Smooth Mousse Foundation  14.79
# 8               Revlon New Complexion One-Step Makeup  18.29
# 9       Maybelline Fit Me Shine-Free Foundation Stick  10.99
# 10           Maybelline Dream Matte Mousse Foundation  14.79
# 11       e.l.f. Studio HD Mattifying Cream Foundation   9.99
# 28  With CoverGirl's Clean Oil Control Makeup, you...     4.0   liquid
# 29  \nPhysicians Formula Nude Wear Touch of Glow F...     4.5   liquid
# 30  Take 5 years off the look of your skin.* This ...     5.0   liquid
# 31  Revlon Age Defying Firming + Lifting Makeup is...     4.5   liquid
# 32  Liquid foundation revolutionized – a fresh lum...     4.0   liquid
# 33  Many women don’t need foundation everywhere.  ...     5.0   liquid
# 34  Physicians Formula Youthful Wear Spotless Foun...     4.7   liquid
# 35  \n        Truly flawless, natural-looking skin...     5.0   liquid
# 36  Almay Smart Shade™ makeup makes it easy to fin...     4.5   liquid
# 37  Introducing a breakthrough in age minimizing m...     4.3   liquid
# 38  Almay Smart Shade™ anti-aging makeup makes it ...     4.2   liquid
# 39  Longwear meets skincare.tlc truly lasting colo...     4.5   liquid
# 40  CoverGirl Outlast Stay Fabulous 3-in-1 foundat...     4.0   liquid
# 41  Finally, makeup that creates skin so healthy -...     5.0   liquid
# 42  Longwear foundation without the compromise. Ne...     4.3   liquid
# 43  Revlon ColorStay Makeup provides longwearing c...     4.6   liquid
# 44  Dr. Hauschka Foundation features pomegranate e...     4.7   liquid
# 45  Achieve a flawless complexion with the silky s...     4.0   liquid
# 46  Airbrushed perfection made possible:Air-whippe...     4.4   liquid
# 47  Maybelline FIT ME! Matte + Poreless Foundation...     4.4   liquid
# 48  Revlon ColorStay Makeup  provides longwearing ...     3.8   liquid
# 49  True Match Super-Blendable Makeup precisely ma...     4.1   liquid
# 50  It’s face makeup that fits you!Features: No oi...     3.8   liquid
# 51  Smooth and conceal fine lines and imperfection...     4.1   liquid
# 52  Achieve even skin tone \nand naturally radiant...     3.8   liquid
#
#                   tag_list                                 api_featured_image  \
# 0               [Canadian]  //s3.amazonaws.com/donovanbailey/products/api_...
# 1            [Gluten Free]  //s3.amazonaws.com/donovanbailey/products/api_...
# 2            [Gluten Free]  //s3.amazonaws.com/donovanbailey/products/api_...
# 3                       []  //s3.amazonaws.com/donovanbailey/products/api_...
# 4                [Natural]  //s3.amazonaws.com/donovanbailey/products/api_...
# 5                       []  //s3.amazonaws.com/donovanbailey/products/api_...
# 6                       []  //s3.amazonaws.com/donovanbailey/products/api_...
# 7                       []  //s3.amazonaws.com/donovanbailey/products/api_...
# 8                       []  //s3.amazonaws.com/donovanbailey/products/api_...
# 9                       []  //s3.amazonaws.com/donovanbailey/products/api_...
# 10                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 11                 [Vegan]  //s3.amazonaws.com/donovanbailey/products/api_...
# 12  [Gluten Free, Natural]  //s3.amazonaws.com/donovanbailey/products/api_...
# 13                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 14                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 15           [Gluten Free]  //s3.amazonaws.com/donovanbailey/products/api_...
# 16           [Gluten Free]  //s3.amazonaws.com/donovanbailey/products/api_...
# 17     [Canadian, Natural]  //s3.amazonaws.com/donovanbailey/products/api_...
# 18                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 19           [Gluten Free]  //s3.amazonaws.com/donovanbailey/products/api_...
# 20     [Canadian, Natural]  //s3.amazonaws.com/donovanbailey/products/api_...
# 21  [Gluten Free, Natural]  //s3.amazonaws.com/donovanbailey/products/api_...
# 22                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 23                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 24                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 25                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 26                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 27                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 28                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 29           [Gluten Free]  //s3.amazonaws.com/donovanbailey/products/api_...
# 30                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 31                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 32                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 33                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 34           [Gluten Free]  //s3.amazonaws.com/donovanbailey/products/api_...
# 35                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 36                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 37                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 38                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 39                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 40                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 41                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 42                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 43                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 44        [Vegan, Natural]  //s3.amazonaws.com/donovanbailey/products/api_...
# 45                 [Vegan]  //s3.amazonaws.com/donovanbailey/products/api_...
# 46                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 47                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 48                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 49                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 50                      []  //s3.amazonaws.com/donovanbailey/products/api_...
# 51     [Canadian, Natural]  //s3.amazonaws.com/donovanbailey/products/api_...
# 52                 [Vegan]  //s3.amazonaws.com/donovanbailey/products/api_...
#
#                                        product_colors  Color Count
# 0   [{'hex_value': '#eabe9b', 'colour_name': 'Ligh...            2
# 1   [{'hex_value': '#fbd0bd', 'colour_name': 'Ligh...            2
# 2                                                  []            0
# 3                                                  []            0
# 4                                                  []            0
# 5                                                  []            0
# 6   [{'hex_value': '#f5dbc8', 'colour_name': 'Nude...            5
# 7                                                  []            0
# 8   [{'hex_value': '#FBCCA0', 'colour_name': 'Ivor...            6
# 9   [{'hex_value': '#FFE4C6', 'colour_name': 'Porc...            6
# 10  [{'hex_value': '#f3d7b3', 'colour_name': 'Clas...            6
# 11  [{'hex_value': '#ECB78F', 'colour_name': 'Sand...            1
# 12  [{'hex_value': '#F1CEAF', 'colour_name': 'Ligh...            3
# 13  [{'hex_value': '#F7B990', 'colour_name': 'Fair...            4
# 14  [{'hex_value': '#E7C1AD', 'colour_name': 'Buff...            4
# 15                                                 []            0
# 16  [{'hex_value': '#ffffee', 'colour_name': 'Tran...            2
# 17  [{'hex_value': '#ecd1bb', 'colour_name': 'Porc...            2
# 18  [{'hex_value': '#FFD59E', 'colour_name': 'Clas...            1
# 19  [{'hex_value': '#f3e2dc', 'colour_name': 'Tran...            3
# 20  [{'hex_value': '#906832', 'colour_name': 'Ambe...            9
# 21  [{'hex_value': '#C28C5E', 'colour_name': 'Oliv...            2
# 22  [{'hex_value': '#D39D7B', 'colour_name': 'Cara...           12
# 23  [{'hex_value': '#9A6438', 'colour_name': 'Coco...            5
# 24  [{'hex_value': '#EAD3B3', 'colour_name': 'Ivor...            5
# 25  [{'hex_value': '#E2A587', 'colour_name': 'Gold...            3
# 26  [{'hex_value': '#F5C8A6', 'colour_name': '105'...            7
# 27                                                 []            0
# 28                                                 []            0
# 29  [{'hex_value': '#f2d7c2', 'colour_name': 'Ligh...            1
# 30                                                 []            0
# 31  [{'hex_value': '#E5BEA5', 'colour_name': 'Warm...            1
# 32  [{'hex_value': '#D09A7A', 'colour_name': 'Buff...            8
# 33  [{'hex_value': '#E9BFA6', 'colour_name': '01 -...            6
# 34  [{'hex_value': '#F6C9A0', 'colour_name': 'Ligh...            2
# 35  [{'hex_value': '#e8c1aa', 'colour_name': 'Medi...            5
# 36  [{'hex_value': '#DFBA9C', 'colour_name': 'Ligh...            3
# 37  [{'hex_value': '#DFBDA2', 'colour_name': 'Clas...            4
# 38  [{'hex_value': '#E3B591', 'colour_name': 'Ligh...            3
# 39  [{'hex_value': '#EBC2A6', 'colour_name': 'Ivor...            3
# 40                                                 []            0
# 41  [{'hex_value': '#f6d6bc', 'colour_name': 'Porc...            5
# 42  [{'hex_value': '#efcba7', 'colour_name': 'Clas...            9
# 43  [{'hex_value': '#F9C79F', 'colour_name': 'Buff...            4
# 44  [{'hex_value': '#eac9a6', 'colour_name': '01 M...            5
# 45  [{'hex_value': '#F1C6A3', 'colour_name': 'Pore...            2
# 46  [{'hex_value': '#FFD59E', 'colour_name': 'Clas...            5
# 47  [{'hex_value': '#fadbc7', 'colour_name': 'Porc...           11
# 48  [{'hex_value': '#FACAAA', 'colour_name': 'Ivor...            3
# 49  [{'hex_value': '#FEDABC', 'colour_name': 'C1 A...           10
# 50  [{'hex_value': '#F7C2A5', 'colour_name': 'Ivor...            4
# 51  [{'hex_value': '#fde8ba', 'colour_name': 'Arct...           13
# 52  [{'hex_value': '#EFC698', 'colour_name': 'Pore...            3

# %% [markdown]
# # Price vs. Rating
# ___
# ### Iteration I:
# Explore Price vs. Rating of individual products through a scatterplot. After analysis found that representation in this way was inconclusive and confusing.

# %%
#Explores the price vs. Rating of individual products
alt.Chart(df).mark_circle(size=200).encode(
    x='Price',
    y='Rating',
    color='Brand',
    tooltip=['Brand', 'Name', 'Price', 'Rating', 'product_link']
).configure_axis(
    grid=True
).interactive()

#Conclusion: Inconclusive and hard to read
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Iteration II:
# In an effort to make the graph more readable, I explored the use of <b>binned scatterplots</b> finding that price did not necessarily equate to quality of product.

# %%
alt.Chart(df).mark_circle(size=200).encode(
    alt.X('Price', bin=True),
    alt.Y('Rating'),
    color='Brand',
    tooltip=['Brand', 'Name', 'Price', 'Rating', 'product_link']
).configure_axis(
    grid=False
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Conclusion:
#
# Price does not equate to quality of product

# %% [markdown]
# # Brand Prices and Quality:
# ___
# After coming to the above conclusion, I decided to explore Brand Prices and Quality of those brands.
#
# ### Iteration I:
#
# In iteration I explored the average price of each brand. I found that in terms of price the most expensive brands were as follows:
#
# <ol>
#     <li>Dr. Hauschka</li>
#     <li>Mineral Fusion</li>
#     <li>Cargo Cosmetics</li>
# </ol>

# %%
alt.Chart(df).mark_bar().encode(
    x = "Brand",
    y = "mean(Price):Q"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Iteration II:
#
# Iteration II explores brands and their overall ratings in terms of Foudnation. Here I found that average ratings were never below an average of 3.5. My conclusion of this iteration found that the best average ratings belonged to the brands `Annabelle`, `Cargo Cosmetics`, and `Marcelle`.

# %%
alt.Chart(df).mark_bar().encode(
    x = "Brand",
    y = "mean(Rating):Q"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Iteration III:
#
# Iteration III explored the combination of average price, average rating, and brand. The bar chart displays the aveage price of the different brands with the darkest bars in the color gradient being the best rated.

# %%
#get the avarge quality vs. average price for each brand
alt.Chart(df).mark_bar().encode(
    alt.X("Brand", axis=alt.Axis(title='Brand')),
    alt.Y("mean(Price):Q", axis=alt.Axis(title='Average Price')),
    color = alt.Color("mean(Rating)", scale=alt.Scale(scheme="goldorange"))
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Conclusion:
#
# From the final iteration it can be concluded that while products like <b>Mineral Fusion</b> are not worth the expensive price products from <b>Dr. Hauschka</b> might be worth the extra money spent. However, you can get better products for a lower price from <b>Cargo Cosmetics</b>, <b>Marcelle</b>, and <b>Annabelle</b>.
#
# The best brand for the lowest price was overwhelmingly `Annabelle`

# %% [markdown]
# # Color Diversity:
# ___
# While it appears clear what brands would be considered the "best bang for your buck" it fails to consider the constant discrimination that occurs within the makeup industry. For this reason, it is important to look at the color diversity of brands and products.

# %% [markdown]
# ### Iteration I:
#
# Iteration I explores the cost of products in relation to the amout of colors provided for that individual product. As shown below it is found that price and color diversity have little to no relation with most products.

# %%
alt.Chart(df).mark_circle(size=200).encode(
    alt.X("Price", bin=True),
    alt.Y("Color Count", axis=alt.Axis(title='Color Diversity')),
    color="Brand"
).configure_axis(
    grid=False
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    alt.X("Price", bin=True),
    alt.Y("mean(Color Count)", axis=alt.Axis(title='Color Diversity')),
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Iteration II: Brands and Color Diversity
#
# In iteration II I wanted to explore how brands fair with color diversity. Finding that brands such as `Pure Anada`, `Maybeline`, and `L'Oreal` have the best color diversity.

# %%
alt.Chart(df).mark_bar().encode(
    alt.X("Brand"),
    alt.Y("Color Count", axis=alt.Axis(title='Color Diversity'))
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Iteration III: Cost and Diversity
#
# From this, I wanted to add the extra layer of looking at the price. Seeing if cheaper or more expensive brands provided better color diversity. From the graph below I display each brands, color diversity with the darker bars showing higher prices and lighter bars showing lower prices.
#
# From this we once again see that price doesn't necessarily equate to color diversity. It does however, give us insight into the ethicacy and market that quite a lot of brands are missing out on.

# %%
alt.Chart(df).mark_bar().encode(
    alt.X("Brand"),
    alt.Y("mean(Color Count)", axis=alt.Axis(title='Color Diversity')),
    color = alt.Color("mean(Price)", scale=alt.Scale(scheme="yellowgreenblue"))
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Iteration IV: Rating and Diversity
#
# I was then curious to see how brand ratings compared to their color diversity. <b>Are these more diverser products providing quality?</b> The graph below once again displays Brand vs. Color Diversity with higher rated products being dark blue, and lower rated products being light green.
#
# I found it once again interesting that brand average rating and color diversity didn't have too great of a relation.

# %%
alt.Chart(df).mark_bar().encode(
    alt.X("Brand"),
    alt.Y("mean(Color Count)", axis=alt.Axis(title='Color Diversity')),
    color = alt.Color("mean(Rating)", scale=alt.Scale(scheme="goldorange"))
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_circle().encode(
    alt.X("Brand", axis=alt.Axis(title='Brand')),
    alt.Y("count(product_colors)", axis=alt.Axis(title='Color Diversity')),
    color = alt.Color("mean(Price)", scale=alt.Scale(scheme="goldorange")),
    size = "mean(Rating)",
    tooltip=['Brand', 'mean(Price)', 'mean(Rating)', 'website_link']
).configure_axis(
    grid=False
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_circle().encode(
    alt.X('Brand', axis=alt.Axis(title='Brand')),
    alt.Y('mean(Price)', axis=alt.Axis(title='Average Price')),
    color = alt.Color('count(product_colors)', scale=alt.Scale(scheme="goldorange")),
    size = "mean(Rating)",
    tooltip = ['Brand', 'mean(Price)', 'mean(Rating)', 'website_link']
).configure_axis(
    grid=False
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# # Final Thoughts:
# ___
# ### Price vs. Rating
#
# Price does not equate to quality of product
#
# ### Brand Prices and Quality
#
# Most expensive brands:
# <ol>
#     <li>Dr. Hauschka</li>
#     <li>Mineral Fusion</li>
#     <li>Cargo Cosmetics</li>
# </ol>
#
# Best rated brands:
# <ol>
#     <li>Annabelle</li>
#     <li>Cargo Cosmetics</li>
#     <li>Marcelle</li>
# </ol>
#
# While products like <b>Mineral Fusion</b> are not worth the expensive price products from <b>Dr. Hauschka</b> might be worth the extra money spent. However, you can get better products for a lower price from <b>Cargo Cosmetics</b>, <b>Marcelle</b>, and <b>Annabelle</b>. The best brand for the lowest price was overwhelmingly `Annabelle`
#
# ### Color Diversity
#
# Overwhelmingly, color diversity is not considered into account in terms of cost or ratings of products.
# Brands such as `Pure Anada`, `Maybeline`, and `L'Oreal` have the greatest color diversity.
