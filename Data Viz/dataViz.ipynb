# %%
import pandas as pd
import altair as alt
from vega_datasets import data

# %%
file = pd.read_json('https://makeup-api.herokuapp.com/api/v1/products.json?product_type=foundation')
df = pd.DataFrame(file)

#rename columns in dataframe
df.rename(columns={'id': 'ID', 'brand': 'Brand', 'name':'Name', 'price':'Price', 'rating': 'Rating', 'category': 'Category'}, inplace=True)
# drop all entries where rating = NaN and brand = null
df.dropna(subset=['Rating', 'Brand'], inplace=True)
#remove price_sign, currency, product_type, created_at, updated_at, product_api_url
df = df.drop(columns=['price_sign', 'currency', 'product_type', 'created_at', 'updated_at', 'product_api_url'])
df
# Out:
#       ID               Brand  \
# 101  389            marcelle
# 102  388  physicians formula
# 103  387  physicians formula
# 104  386           covergirl
# 105  385               sante
# 106  384           covergirl
# 107  383              revlon
# 108  382          maybelline
# 109  381              revlon
# 110  380          maybelline
# 111  379          maybelline
# 112  378              e.l.f.
# 116  374  physicians formula
# 117  373                 nyx
# 119  371              milani
# 120  369  physicians formula
# 121  368  physicians formula
# 122  367          pure anada
# 123  366          maybelline
# 124  365  physicians formula
# 125  364          pure anada
# 127  356      mineral fusion
# 128  354          maybelline
# 129  353          maybelline
# 130  352                 nyx
# 131  350             l'oreal
# 132  349           covergirl
# 136  344           covergirl
# 139  341           covergirl
# 140  340  physicians formula
# 142  338           covergirl
# 144  336              revlon
# 145  335             l'oreal
# 146  334     cargo cosmetics
# 147  333  physicians formula
# 148  332           annabelle
# 149  331               almay
# 150  330             l'oreal
# 151  329               almay
# 152  328               almay
# 153  327           covergirl
# 154  326             l'oreal
# 155  325             l'oreal
# 156  324              revlon
# 157  323        dr. hauschka
# 158  322              e.l.f.
# 159  321          maybelline
# 160  320          maybelline
# 161  319              revlon
# 162  318             l'oreal
# 163  317          maybelline
# 164  316          pure anada
# 165  315              e.l.f.
#
#                                                   Name  Price  \
# 101                 Marcelle BB Cream-to-Powder Makeup  22.99
# 102  Physicians Formula Super BB All-in-1 Beauty Ba...  12.99
# 103  Physicians Formula Nude Wear Touch of Glow Sti...  12.99
# 104        CoverGirl & Olay Simply Ageless Foundation   15.99
# 105                        Sante Soft Cream Foundation  27.49
# 106    CoverGirl Ultimate Finish Liquid Powder Makeup    9.99
# 107              Revlon Colorstay Whipped Creme Makeup  19.99
# 108          Maybelline Dream Smooth Mousse Foundation  14.79
# 109              Revlon New Complexion One-Step Makeup  18.29
# 110      Maybelline Fit Me Shine-Free Foundation Stick  10.99
# 111           Maybelline Dream Matte Mousse Foundation  14.79
# 112       e.l.f. Studio HD Mattifying Cream Foundation   9.99
# 116  Physicians Formula Mineral Wear Talc-Free All-...  20.49
# 117                       NYX Mineral Stick Foundation  11.99
# 119                      Milani Cream-To-Powder Makeup  10.99
# 120    Physicians Formula Mineral Wear Correcting Kit   29.99
# 121  Physicians Formula Mineral Wear Airbrushing Pr...  19.99
# 122      Pure Anada Pressed Sheer Matte Foundation Pan  19.00
# 123  Maybelline Mineral Power Natural Perfecting Po...  14.99
# 124  Physicians Formula Mineral Wear Airbrushing Lo...  14.99
# 125               Pure Anada Loose Mineral Foundation   12.00
# 158  Achieve a flawless complexion with the silky s...     4.0   liquid
# 159  Airbrushed perfection made possible:Air-whippe...     4.4   liquid
# 160  Maybelline FIT ME! Matte + Poreless Foundation...     4.4   liquid
# 161  Revlon ColorStay Makeup  provides longwearing ...     3.8   liquid
# 162  True Match Super-Blendable Makeup precisely ma...     4.1   liquid
# 163  It’s face makeup that fits you!Features: No oi...     3.8   liquid
# 164  Smooth and conceal fine lines and imperfection...     4.1   liquid
# 165  Achieve even skin tone \nand naturally radiant...     3.8   liquid
#
#                    tag_list  \
# 101              [Canadian]
# 102           [Gluten Free]
# 103           [Gluten Free]
# 104                      []
# 105               [Natural]
# 106                      []
# 107                      []
# 108                      []
# 109                      []
# 110                      []
# 111                      []
# 112                 [Vegan]
# 116  [Gluten Free, Natural]
# 117                      []
# 119                      []
# 120           [Gluten Free]
# 121           [Gluten Free]
# 122     [Canadian, Natural]
# 123                      []
# 124           [Gluten Free]
# 125     [Canadian, Natural]
# 127  [Gluten Free, Natural]
# 128                      []
# 129                      []
# 130                      []
# 131                      []
# 132                      []
# 136                      []
# 139                      []
# 140           [Gluten Free]
# 142                      []
# 144                      []
# 145                      []
# 146                      []
# 147           [Gluten Free]
# 148                      []
# 149                      []
# 150                      []
# 151                      []
# 152                      []
# 153                      []
# 154                      []
# 155                      []
# 156                      []
# 157        [Vegan, Natural]
# 158                 [Vegan]
# 159                      []
# 160                      []
# 161                      []
# 162                      []
# 163                      []
# 164     [Canadian, Natural]
# 165                 [Vegan]
#
#                                     api_featured_image  \
# 101  //s3.amazonaws.com/donovanbailey/products/api_...
# 102  //s3.amazonaws.com/donovanbailey/products/api_...
# 103  //s3.amazonaws.com/donovanbailey/products/api_...
# 104  //s3.amazonaws.com/donovanbailey/products/api_...
# 105  //s3.amazonaws.com/donovanbailey/products/api_...
# 106  //s3.amazonaws.com/donovanbailey/products/api_...
# 107  //s3.amazonaws.com/donovanbailey/products/api_...
# 108  //s3.amazonaws.com/donovanbailey/products/api_...
# 109  //s3.amazonaws.com/donovanbailey/products/api_...
# 110  //s3.amazonaws.com/donovanbailey/products/api_...
# 111  //s3.amazonaws.com/donovanbailey/products/api_...
# 112  //s3.amazonaws.com/donovanbailey/products/api_...
# 116  //s3.amazonaws.com/donovanbailey/products/api_...
# 117  //s3.amazonaws.com/donovanbailey/products/api_...
# 119  //s3.amazonaws.com/donovanbailey/products/api_...
# 120  //s3.amazonaws.com/donovanbailey/products/api_...
# 121  //s3.amazonaws.com/donovanbailey/products/api_...
# 122  //s3.amazonaws.com/donovanbailey/products/api_...
# 123  //s3.amazonaws.com/donovanbailey/products/api_...
# 124  //s3.amazonaws.com/donovanbailey/products/api_...
# 125  //s3.amazonaws.com/donovanbailey/products/api_...
# 127  //s3.amazonaws.com/donovanbailey/products/api_...
# 128  //s3.amazonaws.com/donovanbailey/products/api_...
# 129  //s3.amazonaws.com/donovanbailey/products/api_...
# 130  //s3.amazonaws.com/donovanbailey/products/api_...
# 131  //s3.amazonaws.com/donovanbailey/products/api_...
# 132  //s3.amazonaws.com/donovanbailey/products/api_...
# 136  //s3.amazonaws.com/donovanbailey/products/api_...
# 139  //s3.amazonaws.com/donovanbailey/products/api_...
# 140  //s3.amazonaws.com/donovanbailey/products/api_...
# 142  //s3.amazonaws.com/donovanbailey/products/api_...
# 144  //s3.amazonaws.com/donovanbailey/products/api_...
# 145  //s3.amazonaws.com/donovanbailey/products/api_...
# 146  //s3.amazonaws.com/donovanbailey/products/api_...
# 147  //s3.amazonaws.com/donovanbailey/products/api_...
# 148  //s3.amazonaws.com/donovanbailey/products/api_...
# 149  //s3.amazonaws.com/donovanbailey/products/api_...
# 150  //s3.amazonaws.com/donovanbailey/products/api_...
# 151  //s3.amazonaws.com/donovanbailey/products/api_...
# 152  //s3.amazonaws.com/donovanbailey/products/api_...
# 153  //s3.amazonaws.com/donovanbailey/products/api_...
# 154  //s3.amazonaws.com/donovanbailey/products/api_...
# 155  //s3.amazonaws.com/donovanbailey/products/api_...
# 156  //s3.amazonaws.com/donovanbailey/products/api_...
# 157  //s3.amazonaws.com/donovanbailey/products/api_...
# 158  //s3.amazonaws.com/donovanbailey/products/api_...
# 159  //s3.amazonaws.com/donovanbailey/products/api_...
# 160  //s3.amazonaws.com/donovanbailey/products/api_...
# 161  //s3.amazonaws.com/donovanbailey/products/api_...
# 162  //s3.amazonaws.com/donovanbailey/products/api_...
# 163  //s3.amazonaws.com/donovanbailey/products/api_...
# 164  //s3.amazonaws.com/donovanbailey/products/api_...
# 165  //s3.amazonaws.com/donovanbailey/products/api_...
#
#                                         product_colors
# 101  [{'hex_value': '#eabe9b', 'colour_name': 'Ligh...
# 102  [{'hex_value': '#fbd0bd', 'colour_name': 'Ligh...
# 103                                                 []
# 104                                                 []
# 105                                                 []
# 106                                                 []
# 107  [{'hex_value': '#f5dbc8', 'colour_name': 'Nude...
# 108                                                 []
# 109  [{'hex_value': '#FBCCA0', 'colour_name': 'Ivor...
# 110  [{'hex_value': '#FFE4C6', 'colour_name': 'Porc...
# 111  [{'hex_value': '#f3d7b3', 'colour_name': 'Clas...
# 112  [{'hex_value': '#ECB78F', 'colour_name': 'Sand...
# 116  [{'hex_value': '#F1CEAF', 'colour_name': 'Ligh...
# 117  [{'hex_value': '#F7B990', 'colour_name': 'Fair...
# 119  [{'hex_value': '#E7C1AD', 'colour_name': 'Buff...
# 120                                                 []
# 121  [{'hex_value': '#ffffee', 'colour_name': 'Tran...
# 122  [{'hex_value': '#ecd1bb', 'colour_name': 'Porc...
# 123  [{'hex_value': '#FFD59E', 'colour_name': 'Clas...
# 124  [{'hex_value': '#f3e2dc', 'colour_name': 'Tran...
# 125  [{'hex_value': '#906832', 'colour_name': 'Ambe...
# 127  [{'hex_value': '#C28C5E', 'colour_name': 'Oliv...
# 128  [{'hex_value': '#D39D7B', 'colour_name': 'Cara...
# 129  [{'hex_value': '#9A6438', 'colour_name': 'Coco...
# 130  [{'hex_value': '#EAD3B3', 'colour_name': 'Ivor...
# 131  [{'hex_value': '#E2A587', 'colour_name': 'Gold...
# 132  [{'hex_value': '#F5C8A6', 'colour_name': '105'...
# 136                                                 []
# 139                                                 []
# 140  [{'hex_value': '#f2d7c2', 'colour_name': 'Ligh...
# 142                                                 []
# 144  [{'hex_value': '#E5BEA5', 'colour_name': 'Warm...
# 145  [{'hex_value': '#D09A7A', 'colour_name': 'Buff...
# 146  [{'hex_value': '#E9BFA6', 'colour_name': '01 -...
# 147  [{'hex_value': '#F6C9A0', 'colour_name': 'Ligh...
# 148  [{'hex_value': '#e8c1aa', 'colour_name': 'Medi...
# 149  [{'hex_value': '#DFBA9C', 'colour_name': 'Ligh...
# 150  [{'hex_value': '#DFBDA2', 'colour_name': 'Clas...
# 151  [{'hex_value': '#E3B591', 'colour_name': 'Ligh...
# 152  [{'hex_value': '#EBC2A6', 'colour_name': 'Ivor...
# 153                                                 []
# 154  [{'hex_value': '#f6d6bc', 'colour_name': 'Porc...
# 155  [{'hex_value': '#efcba7', 'colour_name': 'Clas...
# 156  [{'hex_value': '#F9C79F', 'colour_name': 'Buff...
# 157  [{'hex_value': '#eac9a6', 'colour_name': '01 M...
# 158  [{'hex_value': '#F1C6A3', 'colour_name': 'Pore...
# 159  [{'hex_value': '#FFD59E', 'colour_name': 'Clas...
# 160  [{'hex_value': '#fadbc7', 'colour_name': 'Porc...
# 161  [{'hex_value': '#FACAAA', 'colour_name': 'Ivor...
# 162  [{'hex_value': '#FEDABC', 'colour_name': 'C1 A...
# 163  [{'hex_value': '#F7C2A5', 'colour_name': 'Ivor...
# 164  [{'hex_value': '#fde8ba', 'colour_name': 'Arct...
# 165  [{'hex_value': '#EFC698', 'colour_name': 'Pore...

# %%
alt.Chart(df).mark_circle(size=200).encode(
    x='Price',
    y='Rating',
    color='Brand',
    tooltip=['Brand', 'Name', 'Price', 'Rating', 'product_link']
).interactive()
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_circle(size=250).encode(
    alt.X('Price:Q', bin=True),
    alt.Y('Rating:Q', bin=True),
    color='Brand',
    tooltip=['Brand', 'Name', 'Price', 'Rating', 'product_link']
)
# Out:
# alt.Chart(...)

# %%
#get the avarge quality vs. average price for each brand
alt.Chart(df).mark_bar().encode(
    x = "Brand",
    y = "mean(Price):Q",
    color = alt.Color("mean(Rating)", scale=alt.Scale(scheme="goldorange"))
)
# Out:
# alt.Chart(...)

# %%
#How to display the diversity of each brand

#get the length of the product_colors array for each product
#bunch by Brand

alt.Chart(df).mark_bar().encode(
    x = "Brand",
    y = "count(product_colors)",
    color = alt.Color("mean(Price)", scale=alt.Scale(scheme="goldorange"))
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_circle().encode(
    alt.X("Brand", axis=alt.Axis(title='Brand')),
    alt.Y("count(product_colors)", axis=alt.Axis(title='Color Diversity')),
    color = alt.Color("mean(Price)", scale=alt.Scale(scheme="goldorange")),
    size = "mean(Rating)",
    tooltip=['Brand', 'mean(Price)', 'mean(Rating)', 'website_link']
).configure_axis(
    grid=False
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_circle().encode(
    alt.X('Brand', axis=alt.Axis(title='Brand')),
    alt.Y('mean(Price)', axis=alt.Axis(title='Average Price')),
    color = alt.Color('count(product_colors)', scale=alt.Scale(scheme="goldorange")),
    size = "mean(Rating)",
    tooltip = ['Brand', 'mean(Price)', 'mean(Rating)', 'website_link']
).configure_axis(
    grid=False
).interactive()
# Out:
# alt.Chart(...)
